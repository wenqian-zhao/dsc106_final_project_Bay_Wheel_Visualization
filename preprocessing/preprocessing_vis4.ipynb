# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../dataset/data_cleaned.csv")

# %%
df["start_date"] = df["start_date"].str[5:7].astype(int)

# %%
df
# Out:
#         Unnamed: 0      id  duration  start_date  \
# 0                0  139546       432           1
# 1                1  139547      1523           1
# 2                2  139551       779           1
# 3                3  139553       721           1
# 4                4  139558      1600           1
# ...            ...     ...       ...         ...
# 149065      149065  432964       169           9
# 149066      149066  432959       441           9
# 149067      149067  432957       398           9
# 149068      149068  432952       240           9
# 149069      149069  432951       619           9
#
#                                    start_station_name  start_station_id  \
# 0                             San Francisco City Hall                58
# 1                              Embarcadero at Sansome                60
# 2                                   Steuart at Market                74
# 3                                   Steuart at Market                74
# ...

# %%
ser = df.groupby(["subscription_type", "start_date"])["id"].count()
ser
# Out:
# subscription_type  start_date
# Customer           1               484
#                    2               378
#                    3               571
#                    4               589
#                    5               673
#                    6               561
#                    7               665
#                    8               668
#                    9               486
#                    10              521
#                    11              414
#                    12              298
# Subscriber         1             12001
#                    2              9114
#                    3             11174
#                    4             12014
#                    5             12181
#                    6             12157
#                    7             12609
#                    8             12510
#                    9             13376
#                    10            14861
#                    11            11549
# ...

# %%
res_dict = {"Customer":[], "Subscriber": []}
for i in res_dict:
    temp = ser[i]
    for j in temp:
        res_dict[i].append(j)
res = pd.DataFrame(res_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\zhaow\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
res.index = range(1, 13)
res
# Out:
#     Customer  Subscriber
# 1        484       12001
# 2        378        9114
# 3        571       11174
# 4        589       12014
# 5        673       12181
# 6        561       12157
# 7        665       12609
# 8        668       12510
# 9        486       13376
# 10       521       14861
# 11       414       11549
# 12       298        9216

# %%
res.to_csv("../dataset/data_cleaned_vis4.csv")
